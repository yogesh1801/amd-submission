# %%
# make sure julia is insalled in your local env ( can use docker env if needed but this notebook is made assuming julia is insalled locally  because wanted to save time )
# %env PATH=/root/.juliaup/bin:$PATH
# Out:
# env: PATH=/root/.juliaup/bin:$PATH

# %%
import pandas as pd
import subprocess
import tempfile
import os
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

# Read the parquet file
df = pd.read_parquet('julia_code_output_smaller_model.parquet')

successful_tasks = []
failed_tasks = []

print(f"Starting tests for {len(df)} tasks...")
print(f"{'='*80}\n")

def run_julia_test(idx, task_id, julia_code, julia_test):
    full_code = f"{julia_code}\n\n{julia_test}"
    with tempfile.NamedTemporaryFile(mode='w', suffix='.jl', delete=False) as f:
        f.write(full_code)
        temp_file = f.name

    try:
        result = subprocess.run(
            ['julia', temp_file],
            capture_output=True,
            text=True,
            timeout=30
        )

        if result.returncode == 0:
            return ("success", task_id, idx, result.stdout, result.stderr)
        else:
            return ("failed", task_id, idx, result.stdout, result.stderr, result.returncode)

    except subprocess.TimeoutExpired:
        return ("timeout", task_id, idx, '', 'Test exceeded 30 second timeout', 'TIMEOUT')

    except Exception as e:
        return ("exception", task_id, idx, '', str(e), 'EXCEPTION')

    finally:
        if os.path.exists(temp_file):
            os.remove(temp_file)


# Number of threads — adjust based on your CPU (e.g., 4–8)
MAX_WORKERS = 8

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_task = {
        executor.submit(run_julia_test, idx, row['task_id'], row['julia_code'], row['julia_test']): idx
        for idx, row in df.iterrows()
    }

    for future in as_completed(future_to_task):
        idx = future_to_task[future]
        try:
            status, task_id, row_index, stdout, stderr, *extra = future.result()
            if status == "success":
                print(f"✅ SUCCESS: {task_id} (Row {row_index + 1}/{len(df)})")
                successful_tasks.append(task_id)
            elif status == "failed":
                return_code = extra[0]
                print(f"❌ FAILED: {task_id} (Row {row_index + 1})")
                print(f"   Error output: {stderr[:200]}...")
                failed_tasks.append({
                    'task_id': task_id,
                    'row_index': row_index,
                    'return_code': return_code,
                    'stderr': stderr,
                    'stdout': stdout
                })
            elif status == "timeout":
                print(f"⏱️ TIMEOUT: {task_id}")
                failed_tasks.append({
                    'task_id': task_id,
                    'row_index': row_index,
                    'return_code': 'TIMEOUT',
                    'stderr': stderr,
                    'stdout': stdout
                })
            else:
                print(f"💥 ERROR: {task_id} - {stderr}")
                failed_tasks.append({
                    'task_id': task_id,
                    'row_index': row_index,
                    'return_code': 'EXCEPTION',
                    'stderr': stderr,
                    'stdout': stdout
                })

        except Exception as e:
            print(f"💥 ERROR in future: {e}")

# Print summary
print(f"\n{'='*80}")
print("SUMMARY")
print(f"{'='*80}")
print(f"Total tasks: {len(df)}")
print(f"✅ Successful: {len(successful_tasks)}")
print(f"❌ Failed: {len(failed_tasks)}")
print(f"Success rate: {len(successful_tasks)/len(df)*100:.2f}%")

if failed_tasks:
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    failed_df = pd.DataFrame(failed_tasks)
    failed_df.to_csv(f'failed_tasks_{timestamp}.csv', index=False)
    print(f"\n❌ Failed tasks saved to: failed_tasks_{timestamp}.csv")

    print("\nFailed task IDs:")
    for task in failed_tasks:
        print(f"  - {task['task_id']} (row {task['row_index']})")
else:
    print("\n🎉 All tasks passed!")

print(f"\n{'='*80}")
# Out:
# Starting tests for 1247 tasks...
# ================================================================================
#
# ✅ SUCCESS: task_9 (Row 5/1247)
# ✅ SUCCESS: task_2 (Row 2/1247)
# ✅ SUCCESS: task_0 (Row 1/1247)
# ✅ SUCCESS: task_14 (Row 9/1247)
# ✅ SUCCESS: task_20 (Row 12/1247)
# ❌ FAILED: task_11 (Row 7)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpsdpq4zen.jl:17
# ...
# ❌ FAILED: task_12 (Row 8)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp2e0iz3ih.jl:20
# ...
# ❌ FAILED: task_4 (Row 4)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpw_ssgzjn.jl:21
# ...
# ❌ FAILED: task_3 (Row 3)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp4tl0a5em.jl:47
# ...
# ✅ SUCCESS: task_30 (Row 15/1247)
# ❌ FAILED: task_17 (Row 11)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpe6s4jged.jl:14
# ...
# ❌ FAILED: task_15 (Row 10)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpwz2q3v7r.jl:40
# ...
# ❌ FAILED: task_25 (Row 13)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpk7jsul0r.jl:14
# ...
# ❌ FAILED: task_10 (Row 6)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 1 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpgzzs2ijn.jl:7
# ...
# ✅ SUCCESS: task_42 (Row 22/1247)
# ❌ FAILED: task_32 (Row 16)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp9fdd70m0.jl:8
# ...
# ❌ FAILED: task_29 (Row 14)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp8r21z5sy.jl:7
# ...
# ❌ FAILED: task_35 (Row 17)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpqckgho85.jl:11
# ...
# ❌ FAILED: task_36 (Row 18)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp3s1g1g68.jl:20
# ...
# ❌ FAILED: task_39 (Row 20)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp7lm_6p3m.jl:20:51
#         left_child = _construct_bst(values[1:mid-1], nothing, nothing)
#         right_child = _construct_bst(values[mid+1:], nothing, n...
# ✅ SUCCESS: task_53 (Row 26/1247)
# ❌ FAILED: task_37 (Row 19)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpmz8gao0d.jl:45
# ...
# ✅ SUCCESS: task_59 (Row 29/1247)
# ❌ FAILED: task_41 (Row 21)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmprv8kn6vp.jl:35
# ...
# ✅ SUCCESS: task_64 (Row 31/1247)
# ❌ FAILED: task_45 (Row 23)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpamvystbu.jl:11
# ...
# ✅ SUCCESS: task_68 (Row 32/1247)
# ❌ FAILED: task_46 (Row 24)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpbe5qxjmf.jl:11:16
#         stats = Dict()
#         for key, value in report["messages"]
# #              └ ── invalid iteration spec: expected one of `=` `i...
# ✅ SUCCESS: task_77 (Row 34/1247)
# ❌ FAILED: task_51 (Row 25)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpusu8fiek.jl:10
# ...
# ✅ SUCCESS: task_78 (Row 35/1247)
# ❌ FAILED: task_55 (Row 27)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpd0ulm_bc.jl:6:70
#         if config[i] == '[' && config[i+1] == '['
#             j = findfirst((x -> x == ']' && x != ' '), config[i+2:end))
# #            ...
# ❌ FAILED: task_57 (Row 28)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpxi2quwde.jl:6:33
#         end
# #                               ┌─────
#         for i in 2 Int(sqrt(x)) step 1
#             if x % i == 0
#                 ret...
# ✅ SUCCESS: task_84 (Row 38/1247)
# ✅ SUCCESS: task_85 (Row 39/1247)
# ✅ SUCCESS: task_87 (Row 40/1247)
# ✅ SUCCESS: task_93 (Row 42/1247)
# ✅ SUCCESS: task_98 (Row 44/1247)
# ✅ SUCCESS: task_94 (Row 43/1247)
# ❌ FAILED: task_61 (Row 30)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpvkhs78iy.jl:25
# ...
# ❌ FAILED: task_69 (Row 33)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp1lafef4r.jl:16
# ...
# ✅ SUCCESS: task_103 (Row 46/1247)
# ✅ SUCCESS: task_107 (Row 48/1247)
# ✅ SUCCESS: task_111 (Row 50/1247)
# ✅ SUCCESS: task_110 (Row 49/1247)
# ❌ FAILED: task_79 (Row 36)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpmz4s64im.jl:7
# ...
# ❌ FAILED: task_82 (Row 37)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpif6xqf_w.jl:9
# ...
# ✅ SUCCESS: task_114 (Row 53/1247)
# ✅ SUCCESS: task_112 (Row 51/1247)
# ✅ SUCCESS: task_115 (Row 54/1247)
# ✅ SUCCESS: task_113 (Row 52/1247)
# ❌ FAILED: task_89 (Row 41)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpd9bke3m1.jl:6:43
#             if result != "" && result[end] == " "
#                 result = deleteat(result, end)
# #                                     ...
# ❌ FAILED: task_100 (Row 45)
#    Error output: ERROR: LoadError: syntax: "..." expression outside call around /tmp/tmpihy_z39y.jl:5
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpihy_z39y.jl:1
# in expression starting at /tmp/tmpihy_z39y.jl:1
# ...
# ✅ SUCCESS: task_116 (Row 55/1247)
# ✅ SUCCESS: task_119 (Row 57/1247)
# ✅ SUCCESS: task_131 (Row 61/1247)
# ✅ SUCCESS: task_136 (Row 63/1247)
# ❌ FAILED: task_106 (Row 47)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpfk6lqyyg.jl:2:81
# function has_extension(file_path, extension)
#     return substr(string(file_path), length(file_path) - length(extension) + 1, end) == ex...
# ✅ SUCCESS: task_138 (Row 64/1247)
# ✅ SUCCESS: task_141 (Row 65/1247)
# ✅ SUCCESS: task_143 (Row 67/1247)
# ✅ SUCCESS: task_145 (Row 69/1247)
# ❌ FAILED: task_128 (Row 60)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp17pq4heg.jl:13
# ...
# ❌ FAILED: task_127 (Row 59)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp817kobhq.jl:7
# ...
# ❌ FAILED: task_123 (Row 58)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpj6_kcyio.jl:13
# ...
# ❌ FAILED: task_133 (Row 62)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpmmhc5flu.jl:14
# ...
# ✅ SUCCESS: task_152 (Row 72/1247)
# ✅ SUCCESS: task_155 (Row 74/1247)
# ❌ FAILED: task_142 (Row 66)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpb45p9zt2.jl:33
# ...
# ❌ FAILED: task_144 (Row 68)
#    Error output: ERROR: LoadError: Some tests did not pass: 5 passed, 0 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmp60y4jjrl.jl:21
# ...
# ✅ SUCCESS: task_157 (Row 76/1247)
# ❌ FAILED: task_117 (Row 56)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmprzr57twj.jl:22
# ...
# ✅ SUCCESS: task_162 (Row 80/1247)
# ❌ FAILED: task_146 (Row 70)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpzer8u_92.jl:13
# ...
# ✅ SUCCESS: task_163 (Row 81/1247)
# ✅ SUCCESS: task_165 (Row 82/1247)
# ❌ FAILED: task_154 (Row 73)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp94trlzlx.jl:8
# ...
# ✅ SUCCESS: task_167 (Row 83/1247)
# ✅ SUCCESS: task_169 (Row 84/1247)
# ❌ FAILED: task_151 (Row 71)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 0 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmppdnu1t71.jl:17
# ...
# ❌ FAILED: task_156 (Row 75)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpurwxs62h.jl:15
# ...
# ✅ SUCCESS: task_170 (Row 85/1247)
# ✅ SUCCESS: task_174 (Row 87/1247)
# ✅ SUCCESS: task_175 (Row 88/1247)
# ❌ FAILED: task_160 (Row 78)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpbuyfka_0.jl:7
# ...
# ✅ SUCCESS: task_182 (Row 92/1247)
# ❌ FAILED: task_159 (Row 77)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpmiuqcjv7.jl:11
# ...
# ❌ FAILED: task_161 (Row 79)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmphcbage6v.jl:11
# ...
# ✅ SUCCESS: task_189 (Row 95/1247)
# ✅ SUCCESS: task_191 (Row 96/1247)
# ✅ SUCCESS: task_193 (Row 97/1247)
# ❌ FAILED: task_171 (Row 86)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpu0j7ak0t.jl:13
# ...
# ❌ FAILED: task_178 (Row 90)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpdmbw5j98.jl:4:82
#     if n > sentence_length
#         return [tokens[1:sentence_length] vec(zero(String)[1,n-sentence_length+1]]
# #                        ...
# ❌ FAILED: task_176 (Row 89)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpbw6tm_1o.jl:12
# ...
# ❌ FAILED: task_179 (Row 91)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp1wtpk6e7.jl:11
# ...
# ✅ SUCCESS: task_205 (Row 101/1247)
# ❌ FAILED: task_188 (Row 94)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp71ktnsxe.jl:19:4
# @test modify_dict(Dict("key1" => "value1", "key2" => "default2", "key3" => nothing), false) == Dict("key1" => "value1")
# end
# #  └ ── Exp...
# ❌ FAILED: task_185 (Row 93)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpv37ptqgh.jl:13
# ...
# ✅ SUCCESS: task_215 (Row 106/1247)
# ❌ FAILED: task_194 (Row 98)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp4guzy6ct.jl:26
# ...
# ✅ SUCCESS: task_216 (Row 107/1247)
# ✅ SUCCESS: task_217 (Row 108/1247)
# ❌ FAILED: task_210 (Row 104)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpii4i0od1.jl:9:21
#   else
#     mid = ceil((1 + end) / 2)
# #                   └─┘ ── invalid identifier
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpii4i0o...
# ✅ SUCCESS: task_224 (Row 110/1247)
# ❌ FAILED: task_209 (Row 103)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpa03uya1o.jl:7
# ...
# ❌ FAILED: task_195 (Row 99)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp0y1tuasi.jl:7
# ...
# ❌ FAILED: task_196 (Row 100)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpn7ya5zcy.jl:19
# ...
# ✅ SUCCESS: task_225 (Row 111/1247)
# ✅ SUCCESS: task_232 (Row 113/1247)
# ✅ SUCCESS: task_234 (Row 114/1247)
# ❌ FAILED: task_212 (Row 105)
#    Error output: ERROR: LoadError: Some tests did not pass: 4 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpp9tsj1fa.jl:22
# ...
# ✅ SUCCESS: task_238 (Row 117/1247)
# ❌ FAILED: task_207 (Row 102)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpoowxbx6p.jl:23
# ...
# ✅ SUCCESS: task_241 (Row 119/1247)
# ✅ SUCCESS: task_242 (Row 120/1247)
# ✅ SUCCESS: task_243 (Row 121/1247)
# ✅ SUCCESS: task_244 (Row 122/1247)
# ❌ FAILED: task_221 (Row 109)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpsryplhz1.jl:14
# ...
# ✅ SUCCESS: task_245 (Row 123/1247)
# ✅ SUCCESS: task_246 (Row 124/1247)
# ✅ SUCCESS: task_248 (Row 125/1247)
# ❌ FAILED: task_226 (Row 112)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpupwfn85a.jl:18:96
#         # Pad the batch with zeros if necessary
#         padded_batch_ss = [batch_ss ; [ss_padding_index] for _ in 1[end_idx - length(b...
# ✅ SUCCESS: task_252 (Row 127/1247)
# ✅ SUCCESS: task_251 (Row 126/1247)
# ✅ SUCCESS: task_257 (Row 131/1247)
# ❌ FAILED: task_236 (Row 116)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpyi6t7ovd.jl:29
# ...
# ✅ SUCCESS: task_261 (Row 134/1247)
# ❌ FAILED: task_253 (Row 128)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpj8c93mo9.jl:31
# ...
# ❌ FAILED: task_239 (Row 118)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp0f_dfu_s.jl:15
# ...
# ❌ FAILED: task_255 (Row 129)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpuodopyqf.jl:17
# ...
# ❌ FAILED: task_259 (Row 132)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpce870wjr.jl:2:51
# function filter_impurities(impurities, threshold)
#     filtered_substances = [substance for substance, level in impurities if level > th...
# ✅ SUCCESS: task_265 (Row 137/1247)
# ✅ SUCCESS: task_271 (Row 139/1247)
# ❌ FAILED: task_260 (Row 133)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp0623ml1c.jl:2:35
# function match_string(word::String)
#     return word[1] == 'R' && in(['Run', 'Rune', 'Runner'], word)
# #                                 ...
# ✅ SUCCESS: task_272 (Row 140/1247)
# ❌ FAILED: task_235 (Row 115)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 1 failed, 7 errored, 0 broken.
# in expression starting at /tmp/tmpuuab5qc_.jl:82
# ...
# ✅ SUCCESS: task_274 (Row 142/1247)
# ✅ SUCCESS: task_273 (Row 141/1247)
# ✅ SUCCESS: task_275 (Row 143/1247)
# ❌ FAILED: task_262 (Row 135)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmplu73fjrh.jl:24
# ...
# ❌ FAILED: task_256 (Row 130)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 1 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp02c85pfa.jl:7
# ...
# ❌ FAILED: task_269 (Row 138)
#    Error output: ERROR: LoadError: syntax: invalid named tuple element "x -> begin
#     # /tmp/tmpl_v8g73b.jl, line 5
#     x[2]
# end" around /tmp/tmpl_v8g73b.jl:5
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpl_v8g73b.jl...
# ❌ FAILED: task_263 (Row 136)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpg4xdy7zj.jl:27
# ...
# ❌ FAILED: task_281 (Row 147)
#    Error output: ERROR: LoadError: UndefVarError: `User` not defined
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpc2m6izy2.jl:1
# in expression starting at /tmp/tmpc2m6izy2.jl:1
# ...
# ✅ SUCCESS: task_290 (Row 151/1247)
# ❌ FAILED: task_276 (Row 144)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpymqmgkjr.jl:3:16
#     secret_keys = [("alice", "key123"), ("bob", "key456"), ("charlie", "key789")]
#     for account, key in secret_keys
# #              └ ...
# ❌ FAILED: task_278 (Row 145)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpg1wea49g.jl:12:34
#   sqrt_n = sqrt(n)
# #                                ┌
#   for i in 3:div(sqrt_n, 2) step 2
#     if n % i == 0
#       return false
#     end
# ...
# ✅ SUCCESS: task_291 (Row 152/1247)
# ✅ SUCCESS: task_301 (Row 154/1247)
# ✅ SUCCESS: task_304 (Row 157/1247)
# ❌ FAILED: task_288 (Row 149)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 0 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpeyw83wm1.jl:13
# ...
# ❌ FAILED: task_280 (Row 146)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpm3tfnwiv.jl:12
# ...
# ❌ FAILED: task_283 (Row 148)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpcje1mxpf.jl:23
# ...
# ✅ SUCCESS: task_309 (Row 161/1247)
# ❌ FAILED: task_293 (Row 153)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmphd4yjeyu.jl:16
# ...
# ❌ FAILED: task_303 (Row 156)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpuzvzb6xt.jl:37
# ...
# ✅ SUCCESS: task_313 (Row 162/1247)
# ❌ FAILED: task_302 (Row 155)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpxsq7l6kk.jl:37
# ...
# ❌ FAILED: task_289 (Row 150)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpww623_7d.jl:13
# ...
# ✅ SUCCESS: task_321 (Row 165/1247)
# ❌ FAILED: task_306 (Row 158)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp4tkk86d9.jl:16
# ...
# ❌ FAILED: task_307 (Row 159)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpigg1tlcf.jl:7
# ...
# ✅ SUCCESS: task_326 (Row 168/1247)
# ✅ SUCCESS: task_327 (Row 169/1247)
# ❌ FAILED: task_308 (Row 160)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp_wmsb4y0.jl:13
# ...
# ✅ SUCCESS: task_330 (Row 171/1247)
# ✅ SUCCESS: task_329 (Row 170/1247)
# ✅ SUCCESS: task_337 (Row 173/1247)
# ✅ SUCCESS: task_338 (Row 174/1247)
# ✅ SUCCESS: task_341 (Row 175/1247)
# ❌ FAILED: task_315 (Row 163)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpp2_zl8jk.jl:17
# ...
# ✅ SUCCESS: task_346 (Row 177/1247)
# ❌ FAILED: task_325 (Row 167)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp9ggr7q87.jl:6:18
#         end
#         for i in 2.sqrt(x) + 1
# #                └┘ ── numeric constant cannot be implicitly multiplied because it ends with...
# ❌ FAILED: task_322 (Row 166)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpy1tnbz90.jl:19
# ...
# ❌ FAILED: task_316 (Row 164)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp5e8if5ti.jl:27
# ...
# ✅ SUCCESS: task_357 (Row 183/1247)
# ❌ FAILED: task_336 (Row 172)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpp4iow83d.jl:7
# ...
# ✅ SUCCESS: task_359 (Row 185/1247)
# ❌ FAILED: task_344 (Row 176)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpsipnkrf8.jl:11
# ...
# ❌ FAILED: task_350 (Row 181)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpa4csjevy.jl:15
# ...
# ✅ SUCCESS: task_361 (Row 187/1247)
# ❌ FAILED: task_347 (Row 178)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpmmquf4or.jl:13
# ...
# ❌ FAILED: task_349 (Row 180)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp1ng_0k1v.jl:23
# ...
# ✅ SUCCESS: task_364 (Row 189/1247)
# ❌ FAILED: task_348 (Row 179)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp9gh61s32.jl:16
# ...
# ❌ FAILED: task_353 (Row 182)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpy181w87r.jl:23
# ...
# ✅ SUCCESS: task_368 (Row 191/1247)
# ✅ SUCCESS: task_369 (Row 192/1247)
# ✅ SUCCESS: task_376 (Row 194/1247)
# ✅ SUCCESS: task_379 (Row 197/1247)
# ❌ FAILED: task_360 (Row 186)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp4k7rhpdv.jl:18
# ...
# ❌ FAILED: task_358 (Row 184)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpsa5i3ij6.jl:14
# ...
# ✅ SUCCESS: task_377 (Row 195/1247)
# ✅ SUCCESS: task_382 (Row 199/1247)
# ❌ FAILED: task_378 (Row 196)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp9tt1zql_.jl:11:38
#         result[i] = molecules[1:base]
#         molecules = molecules[base+1:]
# #                                    └ ── missing last ar...
# ❌ FAILED: task_367 (Row 190)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpjpki71ed.jl:10
# ...
# ❌ FAILED: task_373 (Row 193)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpvz3uce5t.jl:10
# ...
# ✅ SUCCESS: task_389 (Row 203/1247)
# ❌ FAILED: task_362 (Row 188)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 1 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmppvdl7mxu.jl:11
# ...
# ✅ SUCCESS: task_394 (Row 206/1247)
# ❌ FAILED: task_380 (Row 198)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpf1tiz7a2.jl:23
# ...
# ✅ SUCCESS: task_400 (Row 209/1247)
# ❌ FAILED: task_385 (Row 200)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp3e7t1las.jl:20
# ...
# ❌ FAILED: task_387 (Row 201)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpiqtyv_e5.jl:16
# ...
# ✅ SUCCESS: task_401 (Row 210/1247)
# ❌ FAILED: task_388 (Row 202)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpf9zsafw4.jl:8
# ...
# ❌ FAILED: task_392 (Row 204)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp0gof5d74.jl:22
# ...
# ❌ FAILED: task_393 (Row 205)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpho4pv044.jl:19
# ...
# ❌ FAILED: task_395 (Row 207)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpod44yjv4.jl:15
# ...
# ✅ SUCCESS: task_410 (Row 216/1247)
# ❌ FAILED: task_403 (Row 212)
#    Error output: ERROR: LoadError: UndefVarError: `left` not defined
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpuinhll9r.jl:1
# in expression starting at /tmp/tmpuinhll9r.jl:1
# ...
# ❌ FAILED: task_399 (Row 208)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpdhaodwrx.jl:23
# ...
# ✅ SUCCESS: task_412 (Row 217/1247)
# ✅ SUCCESS: task_414 (Row 219/1247)
# ❌ FAILED: task_402 (Row 211)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpsvtq45xa.jl:20
# ...
# ✅ SUCCESS: task_417 (Row 222/1247)
# ❌ FAILED: task_404 (Row 213)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp_0iriid5.jl:14
# ...
# ❌ FAILED: task_406 (Row 214)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpmdt5q1t4.jl:14
# ...
# ✅ SUCCESS: task_418 (Row 223/1247)
# ✅ SUCCESS: task_424 (Row 226/1247)
# ✅ SUCCESS: task_428 (Row 228/1247)
# ❌ FAILED: task_407 (Row 215)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp8ww8ypfc.jl:25
# ...
# ❌ FAILED: task_413 (Row 218)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpw08okfsk.jl:24
# ...
# ✅ SUCCESS: task_429 (Row 229/1247)
# ✅ SUCCESS: task_430 (Row 230/1247)
# ❌ FAILED: task_415 (Row 220)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp1_cf4buy.jl:11
# ...
# ❌ FAILED: task_416 (Row 221)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpk6565o8e.jl:7
# ...
# ✅ SUCCESS: task_435 (Row 233/1247)
# ✅ SUCCESS: task_440 (Row 235/1247)
# ❌ FAILED: task_427 (Row 227)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpw1dfs7uj.jl:25
# ...
# ❌ FAILED: task_421 (Row 225)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpviaf2ggd.jl:30
# ...
# ✅ SUCCESS: task_442 (Row 237/1247)
# ✅ SUCCESS: task_447 (Row 239/1247)
# ✅ SUCCESS: task_449 (Row 240/1247)
# ❌ FAILED: task_434 (Row 232)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmppp1zxa9o.jl:7:97
#         host_name = contests[i][3]
#         push(string("Index: $i, Contest Name: $contest_name ($duration, Hosted by $host_name)") into...
# ❌ FAILED: task_432 (Row 231)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpzpkzg8w5.jl:14
# ...
# ❌ FAILED: task_419 (Row 224)
#    Error output: ERROR: LoadError: MethodError: no method matching push!(::String, ::String)
#
# Closest candidates are:
#   push!(::Any, ::Any, !Matched::Any)
#    @ Base abstractarray.jl:3421
#   push!(::Any, ::Any, !Matched...
# ❌ FAILED: task_436 (Row 234)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpw0iml3iz.jl:11
# ...
# ✅ SUCCESS: task_454 (Row 243/1247)
# ✅ SUCCESS: task_459 (Row 244/1247)
# ❌ FAILED: task_441 (Row 236)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpmtcvwcvt.jl:20
# ...
# ✅ SUCCESS: task_467 (Row 248/1247)
# ✅ SUCCESS: task_468 (Row 249/1247)
# ❌ FAILED: task_450 (Row 241)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpfoinc1s9.jl:11
# ...
# ❌ FAILED: task_462 (Row 245)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpocyykh94.jl:1:55
# function generate_segmentation_commands(start::Int64, end::Int64, step::Int64)
# #                                                     └ ...
# ✅ SUCCESS: task_477 (Row 252/1247)
# ❌ FAILED: task_453 (Row 242)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp8_6cb0_d.jl:25
# ...
# ❌ FAILED: task_443 (Row 238)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpfp1ve88p.jl:21
# ...
# ❌ FAILED: task_463 (Row 246)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpuzx8h46m.jl:11
# ...
# ✅ SUCCESS: task_479 (Row 254/1247)
# ✅ SUCCESS: task_482 (Row 256/1247)
# ✅ SUCCESS: task_483 (Row 257/1247)
# ❌ FAILED: task_464 (Row 247)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp7bxnpdm7.jl:18
# ...
# ❌ FAILED: task_472 (Row 250)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpcec57xfi.jl:7
# ...
# ✅ SUCCESS: task_488 (Row 260/1247)
# ✅ SUCCESS: task_486 (Row 259/1247)
# ❌ FAILED: task_474 (Row 251)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpr34qw9ha.jl:17
# ...
# ✅ SUCCESS: task_496 (Row 264/1247)
# ✅ SUCCESS: task_495 (Row 263/1247)
# ✅ SUCCESS: task_494 (Row 262/1247)
# ✅ SUCCESS: task_498 (Row 265/1247)
# ✅ SUCCESS: task_500 (Row 267/1247)
# ✅ SUCCESS: task_504 (Row 268/1247)
# ❌ FAILED: task_481 (Row 255)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpwldwwc3a.jl:14
# ...
# ❌ FAILED: task_478 (Row 253)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpkyl1fqay.jl:14
# ...
# ✅ SUCCESS: task_506 (Row 270/1247)
# ✅ SUCCESS: task_512 (Row 273/1247)
# ✅ SUCCESS: task_508 (Row 272/1247)
# ✅ SUCCESS: task_513 (Row 274/1247)
# ❌ FAILED: task_493 (Row 261)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpjo46p8m1.jl:15
# ...
# ❌ FAILED: task_484 (Row 258)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp0jn_9_2z.jl:7
# ...
# ✅ SUCCESS: task_518 (Row 277/1247)
# ✅ SUCCESS: task_521 (Row 279/1247)
# ❌ FAILED: task_499 (Row 266)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp26qcpbp_.jl:13
# ...
# ❌ FAILED: task_505 (Row 269)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmp2z_orlfq.jl:12:53
#         if has_dot
#             ext = file_name[file_name.find('.') + 1:]
# #                                                   └ ── miss...
# ✅ SUCCESS: task_524 (Row 281/1247)
# ❌ FAILED: task_514 (Row 275)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpftc5vete.jl:14
# ...
# ❌ FAILED: task_519 (Row 278)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpjtknsw0l.jl:33
# ...
# ✅ SUCCESS: task_532 (Row 285/1247)
# ❌ FAILED: task_507 (Row 271)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 1 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpajua1ig6.jl:11
# ...
# ❌ FAILED: task_522 (Row 280)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp6_z481a9.jl:14
# ...
# ✅ SUCCESS: task_539 (Row 288/1247)
# ❌ FAILED: task_526 (Row 282)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp7b1n71u4.jl:11
# ...
# ✅ SUCCESS: task_540 (Row 289/1247)
# ❌ FAILED: task_531 (Row 284)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpjm_ixflz.jl:13
# ...
# ✅ SUCCESS: task_544 (Row 291/1247)
# ❌ FAILED: task_529 (Row 283)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpu9f31roy.jl:16
# ...
# ✅ SUCCESS: task_545 (Row 292/1247)
# ❌ FAILED: task_516 (Row 276)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmp9byyiufn.jl:13
# ...
# ✅ SUCCESS: task_546 (Row 293/1247)
# ❌ FAILED: task_538 (Row 287)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmplth2rrvx.jl:8
# ...
# ✅ SUCCESS: task_560 (Row 299/1247)
# ❌ FAILED: task_543 (Row 290)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpsmpfhrmt.jl:17
# ...
# ❌ FAILED: task_552 (Row 297)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpwj3ttsce.jl:4:5
#     a = join(filter(c -> isalnum(c), lowercase(a))
#     b = join(filter(c -> isalnum(c), lowercase(b))
# #   └────────────────────────────┘...
# ❌ FAILED: task_550 (Row 295)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpz_6ak_6q.jl:12
# ...
# ❌ FAILED: task_551 (Row 296)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpyms_nv44.jl:9
# ...
# ❌ FAILED: task_549 (Row 294)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp1gcjj_xk.jl:11
# ...
# ❌ FAILED: task_556 (Row 298)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpg59bhjjt.jl:11
# ...
# ❌ FAILED: task_570 (Row 303)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpy81s1_0y.jl:6:122
#         s_lower = string(lowercase(s))
#         if length(s_lower) > 1 && s_lower[end] ∈ vowels && s_lower[end] != any(c for c in vowel...
# ❌ FAILED: task_562 (Row 301)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpjtyiwp7j.jl:18
# ...
# ✅ SUCCESS: task_576 (Row 307/1247)
# ❌ FAILED: task_561 (Row 300)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 1 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmphrrm1qt_.jl:23
# ...
# ❌ FAILED: task_574 (Row 305)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpt6e96v8m.jl:12
# ...
# ✅ SUCCESS: task_578 (Row 309/1247)
# ✅ SUCCESS: task_579 (Row 310/1247)
# ❌ FAILED: task_572 (Row 304)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 5 errored, 0 broken.
# in expression starting at /tmp/tmpn202tsnr.jl:15
# ...
# ✅ SUCCESS: task_580 (Row 311/1247)
# ❌ FAILED: task_563 (Row 302)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 1 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpdwfvstgi.jl:28
# ...
# ✅ SUCCESS: task_589 (Row 315/1247)
# ✅ SUCCESS: task_590 (Row 316/1247)
# ❌ FAILED: task_575 (Row 306)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpkwvus9kh.jl:71
# ...
# ❌ FAILED: task_577 (Row 308)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpra3icx0d.jl:3:10
#     num_dict = Dict()
#     for i, num in enumerate(nums)
# #        └ ── invalid iteration spec: expected one of `=` `in` or `∈`
# Stacktrac...
# ✅ SUCCESS: task_597 (Row 320/1247)
# ❌ FAILED: task_581 (Row 312)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpevte3491.jl:10:10
#   end
#   unique flat_list
# #        └───────┘ ── Expected `end`
# Stacktrace:
#  [1] top-level scope
#    @ /tmp/tmpevte3491.jl:10
# in expressi...
# ❌ FAILED: task_582 (Row 313)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp951minm1.jl:13
# ...
# ✅ SUCCESS: task_598 (Row 321/1247)
# ❌ FAILED: task_586 (Row 314)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpe7q8z0l4.jl:15
# ...
# ✅ SUCCESS: task_601 (Row 323/1247)
# ✅ SUCCESS: task_599 (Row 322/1247)
# ❌ FAILED: task_592 (Row 317)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpm6fj7pqs.jl:20
# ...
# ✅ SUCCESS: task_604 (Row 325/1247)
# ✅ SUCCESS: task_607 (Row 327/1247)
# ❌ FAILED: task_595 (Row 319)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpv65mtjb3.jl:17
# ...
# ❌ FAILED: task_594 (Row 318)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpbop30a6r.jl:16
# ...
# ❌ FAILED: task_603 (Row 324)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp2p4zuh48.jl:11
# ...
# ❌ FAILED: task_606 (Row 326)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpcterxbw2.jl:10
# ...
# ✅ SUCCESS: task_612 (Row 332/1247)
# ✅ SUCCESS: task_619 (Row 335/1247)
# ❌ FAILED: task_608 (Row 328)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpxf48f5m7.jl:7
# ...
# ✅ SUCCESS: task_621 (Row 336/1247)
# ✅ SUCCESS: task_622 (Row 337/1247)
# ❌ FAILED: task_609 (Row 329)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmplb9zm5os.jl:10
# ...
# ❌ FAILED: task_611 (Row 331)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmplzf8635b.jl:23
# ...
# ✅ SUCCESS: task_625 (Row 340/1247)
# ✅ SUCCESS: task_628 (Row 342/1247)
# ❌ FAILED: task_610 (Row 330)
#    Error output: ERROR: LoadError: MethodError: no method matching WhatsAppDatabaseWA(; database::String)
#
# Closest candidates are:
#   WhatsAppDatabaseWA(!Matched::String) got unsupported keyword argument "database"
#    ...
# ❌ FAILED: task_616 (Row 334)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmp3m5y1_cf.jl:17
# ...
# ❌ FAILED: task_615 (Row 333)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmppyjz4iwe.jl:13
# ...
# ❌ FAILED: task_624 (Row 339)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmped7o6qqo.jl:3:15
#     if isempty(domain) || isempty(user_pool_id)
#         throw ArgumentError("Domain and user pool ID must be non-empty strings")
# #     ...
# ❌ FAILED: task_623 (Row 338)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp0j2wjepw.jl:7
# ...
# ❌ FAILED: task_627 (Row 341)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp3mpurdi5.jl:14
# ...
# ❌ FAILED: task_633 (Row 345)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp4mo2af62.jl:13
# ...
# ❌ FAILED: task_629 (Row 343)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpaanrov8v.jl:34
# ...
# ❌ FAILED: task_636 (Row 347)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpbwjjiqn5.jl:12
# ...
# ❌ FAILED: task_632 (Row 344)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpwtxs88tp.jl:14
# ...
# ❌ FAILED: task_637 (Row 348)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp3hhqvcbp.jl:12
# ...
# ❌ FAILED: task_634 (Row 346)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp5z32oq_y.jl:13
# ...
# ✅ SUCCESS: task_654 (Row 352/1247)
# ✅ SUCCESS: task_657 (Row 354/1247)
# ✅ SUCCESS: task_660 (Row 355/1247)
# ❌ FAILED: task_641 (Row 349)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp4q16rfc0.jl:19
# ...
# ✅ SUCCESS: task_664 (Row 358/1247)
# ❌ FAILED: task_647 (Row 351)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp8e5t9bql.jl:38
# ...
# ❌ FAILED: task_645 (Row 350)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmphwtb591g.jl:16
# ...
# ❌ FAILED: task_655 (Row 353)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmploeqi41y.jl:15
# ...
# ❌ FAILED: task_662 (Row 356)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpmzpjevth.jl:20
# ...
# ✅ SUCCESS: task_684 (Row 363/1247)
# ✅ SUCCESS: task_690 (Row 365/1247)
# ❌ FAILED: task_673 (Row 360)
#    Error output: ERROR: LoadError: ParseError:
# # Error @ /tmp/tmpy0h706an.jl:3:25
#     total_positive = sum([i for i in instances if i > 0])
#     return "Sufficient" if total_positive >= 100 else "Insufficient"
# #       ...
# ❌ FAILED: task_667 (Row 359)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmphnh55cqb.jl:11
# ...
# ✅ SUCCESS: task_692 (Row 366/1247)
# ✅ SUCCESS: task_702 (Row 368/1247)
# ✅ SUCCESS: task_698 (Row 367/1247)
# ❌ FAILED: task_663 (Row 357)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmp3tvcxhoa.jl:16
# ...
# ✅ SUCCESS: task_704 (Row 370/1247)
# ❌ FAILED: task_675 (Row 361)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmphcz4508s.jl:11
# ...
# ❌ FAILED: task_681 (Row 362)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpv4de6wpr.jl:13
# ...
# ✅ SUCCESS: task_705 (Row 371/1247)
# ✅ SUCCESS: task_706 (Row 372/1247)
# ✅ SUCCESS: task_713 (Row 375/1247)
# ✅ SUCCESS: task_714 (Row 376/1247)
# ❌ FAILED: task_686 (Row 364)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 1 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmp_sg079bq.jl:17
# ...
# ❌ FAILED: task_703 (Row 369)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpyd3_3nm3.jl:20
# ...
# ❌ FAILED: task_712 (Row 374)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpdhab8a2j.jl:11
# ...
# ❌ FAILED: task_710 (Row 373)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp_gjayg7t.jl:14
# ...
# ✅ SUCCESS: task_731 (Row 383/1247)
# ✅ SUCCESS: task_727 (Row 382/1247)
# ❌ FAILED: task_720 (Row 378)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp22vvzt6l.jl:22
# ...
# ❌ FAILED: task_721 (Row 379)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmp1324l8je.jl:21
# ...
# ✅ SUCCESS: task_735 (Row 386/1247)
# ❌ FAILED: task_723 (Row 380)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpe45s15e2.jl:7
# ...
# ❌ FAILED: task_717 (Row 377)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 2 failed, 1 errored, 0 broken.
# in expression starting at /tmp/tmpgw76ico6.jl:39
# ...
# ❌ FAILED: task_725 (Row 381)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpcclo9qcv.jl:17
# ...
# ❌ FAILED: task_732 (Row 384)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmp057xgl41.jl:20
# ...
# ❌ FAILED: task_736 (Row 387)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpwgbq13wb.jl:17
# ...
# ❌ FAILED: task_737 (Row 388)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmprkl9m6tq.jl:11
# ...
# ❌ FAILED: task_733 (Row 385)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpvcbexpwl.jl:17
# ...
# ❌ FAILED: task_741 (Row 390)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpceiekmuk.jl:26
# ...
# ❌ FAILED: task_740 (Row 389)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 0 failed, 2 errored, 0 broken.
# in expression starting at /tmp/tmpoddxff8l.jl:13
# ...
# ✅ SUCCESS: task_750 (Row 396/1247)
# ❌ FAILED: task_742 (Row 391)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpyf4zhh_h.jl:22
# ...
# ✅ SUCCESS: task_751 (Row 397/1247)
# ✅ SUCCESS: task_753 (Row 398/1247)
# ✅ SUCCESS: task_755 (Row 399/1247)
# ❌ FAILED: task_745 (Row 393)
#    Error output: ERROR: LoadError: Some tests did not pass: 2 passed, 1 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpg02ips3r.jl:8
# ...
# ❌ FAILED: task_747 (Row 394)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpyr2ovd4g.jl:18
# ...
# ✅ SUCCESS: task_770 (Row 403/1247)
# ✅ SUCCESS: task_773 (Row 405/1247)
# ✅ SUCCESS: task_774 (Row 406/1247)
# ✅ SUCCESS: task_775 (Row 407/1247)
# ❌ FAILED: task_760 (Row 400)
#    Error output: ERROR: LoadError: Some tests did not pass: 1 passed, 2 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmpr7y2e1am.jl:18
# ...
# ❌ FAILED: task_765 (Row 402)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpjmp18_sd.jl:15
# ...
# ❌ FAILED: task_762 (Row 401)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 3 failed, 0 errored, 0 broken.
# in expression starting at /tmp/tmplro7dxcy.jl:20
# ...
# ✅ SUCCESS: task_782 (Row 411/1247)
# ❌ FAILED: task_772 (Row 404)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
# in expression starting at /tmp/tmpwgxoh5lo.jl:13
# ...
# ✅ SUCCESS: task_780 (Row 410/1247)
# ✅ SUCCESS: task_776 (Row 408/1247)
# ✅ SUCCESS: task_785 (Row 412/1247)
# ✅ SUCCESS: task_798 (Row 414/1247)
# ✅ SUCCESS: task_803 (Row 417/1247)
# ✅ SUCCESS: task_748 (Row 395/1247)
# ✅ SUCCESS: task_805 (Row 418/1247)
# ✅ SUCCESS: task_806 (Row 419/1247)
# ✅ SUCCESS: task_810 (Row 420/1247)
# ❌ FAILED: task_779 (Row 409)
#    Error output: ERROR: LoadError: Some tests did not pass: 0 passed, 0 failed, 6 errored, 0 broken.
# in expression starting at /tmp/tmpckllyz3l.jl:15
# ...
# ...
# Total tasks: 1247
# ✅ Successful: 583
# ❌ Failed: 664
# Success rate: 46.75%
#
# ❌ Failed tasks saved to: failed_tasks_20251026_220851.csv
#
# Failed task IDs:
#   - task_11 (row 6)
#   - task_12 (row 7)
#   - task_4 (row 3)
#   - task_3 (row 2)
#   - task_17 (row 10)
#   - task_15 (row 9)
#   - task_25 (row 12)
#   - task_10 (row 5)
#   - task_32 (row 15)
#   - task_29 (row 13)
#   - task_35 (row 16)
#   - task_36 (row 17)
#   - task_39 (row 19)
#   - task_37 (row 18)
#   - task_41 (row 20)
#   - task_45 (row 22)
#   - task_46 (row 23)
#   - task_51 (row 24)
#   - task_55 (row 26)
#   - task_57 (row 27)
#   - task_61 (row 29)
#   - task_69 (row 32)
#   - task_79 (row 35)
#   - task_82 (row 36)
#   - task_89 (row 40)
#   - task_100 (row 44)
#   - task_106 (row 46)
#   - task_128 (row 59)
#   - task_127 (row 58)
#   - task_123 (row 57)
#   - task_133 (row 61)
#   - task_142 (row 65)
#   - task_144 (row 67)
#   - task_117 (row 55)
#   - task_146 (row 69)
#   - task_154 (row 72)
#   - task_151 (row 70)
#   - task_156 (row 74)
#   - task_160 (row 77)
#   - task_159 (row 76)
#   - task_161 (row 78)
#   - task_171 (row 85)
#   - task_178 (row 89)
#   - task_176 (row 88)
#   - task_179 (row 90)
#   - task_188 (row 93)
#   - task_185 (row 92)
#   - task_194 (row 97)
#   - task_210 (row 103)
#   - task_209 (row 102)
#   - task_195 (row 98)
#   - task_196 (row 99)
#   - task_212 (row 104)
#   - task_207 (row 101)
#   - task_221 (row 108)
#   - task_226 (row 111)
#   - task_236 (row 115)
#   - task_253 (row 127)
#   - task_239 (row 117)
#   - task_255 (row 128)
#   - task_259 (row 131)
#   - task_260 (row 132)
#   - task_235 (row 114)
#   - task_262 (row 134)
#   - task_256 (row 129)
#   - task_269 (row 137)
#   - task_263 (row 135)
#   - task_281 (row 146)
#   - task_276 (row 143)
#   - task_278 (row 144)
#   - task_288 (row 148)
#   - task_280 (row 145)
#   - task_283 (row 147)
#   - task_293 (row 152)
#   - task_303 (row 155)
#   - task_302 (row 154)
#   - task_289 (row 149)
#   - task_306 (row 157)
#   - task_307 (row 158)
#   - task_308 (row 159)
#   - task_315 (row 162)
#   - task_325 (row 166)
#   - task_322 (row 165)
#   - task_316 (row 163)
#   - task_336 (row 171)
#   - task_344 (row 175)
#   - task_350 (row 180)
#   - task_347 (row 177)
#   - task_349 (row 179)
#   - task_348 (row 178)
#   - task_353 (row 181)
#   - task_360 (row 185)
#   - task_358 (row 183)
#   - task_378 (row 195)
#   - task_367 (row 189)
#   - task_373 (row 192)
#   - task_362 (row 187)
#   - task_380 (row 197)
#   - task_385 (row 199)
#   - task_387 (row 200)
#   - task_388 (row 201)
#   - task_392 (row 203)
#   - task_393 (row 204)
#   - task_395 (row 206)
#   - task_403 (row 211)
#   - task_399 (row 207)
#   - task_402 (row 210)
#   - task_404 (row 212)
#   - task_406 (row 213)
#   - task_407 (row 214)
#   - task_413 (row 217)
#   - task_415 (row 219)
#   - task_416 (row 220)
#   - task_427 (row 226)
#   - task_421 (row 224)
#   - task_434 (row 231)
#   - task_432 (row 230)
#   - task_419 (row 223)
#   - task_436 (row 233)
#   - task_441 (row 235)
#   - task_450 (row 240)
#   - task_462 (row 244)
#   - task_453 (row 241)
#   - task_443 (row 237)
#   - task_463 (row 245)
#   - task_464 (row 246)
#   - task_472 (row 249)
#   - task_474 (row 250)
#   - task_481 (row 254)
#   - task_478 (row 252)
#   - task_493 (row 260)
#   - task_484 (row 257)
#   - task_499 (row 265)
#   - task_505 (row 268)
#   - task_514 (row 274)
#   - task_519 (row 277)
#   - task_507 (row 270)
#   - task_522 (row 279)
#   - task_526 (row 281)
#   - task_531 (row 283)
#   - task_529 (row 282)
#   - task_516 (row 275)
#   - task_538 (row 286)
#   - task_543 (row 289)
#   - task_552 (row 296)
#   - task_550 (row 294)
#   - task_551 (row 295)
#   - task_549 (row 293)
#   - task_556 (row 297)
#   - task_570 (row 302)
#   - task_562 (row 300)
#   - task_561 (row 299)
#   - task_574 (row 304)
#   - task_572 (row 303)
#   - task_563 (row 301)
#   - task_575 (row 305)
#   - task_577 (row 307)
#   - task_581 (row 311)
#   - task_582 (row 312)
#   - task_586 (row 313)
#   - task_592 (row 316)
#   - task_595 (row 318)
#   - task_594 (row 317)
#   - task_603 (row 323)
#   - task_606 (row 325)
#   - task_608 (row 327)
#   - task_609 (row 328)
#   - task_611 (row 330)
#   - task_610 (row 329)
#   - task_616 (row 333)
#   - task_615 (row 332)
#   - task_624 (row 338)
#   - task_623 (row 337)
#   - task_627 (row 340)
#   - task_633 (row 344)
#   - task_629 (row 342)
#   - task_636 (row 346)
#   - task_632 (row 343)
#   - task_637 (row 347)
#   - task_634 (row 345)
#   - task_641 (row 348)
#   - task_647 (row 350)
#   - task_645 (row 349)
#   - task_655 (row 352)
#   - task_662 (row 355)
#   - task_673 (row 359)
#   - task_667 (row 358)
#   - task_663 (row 356)
#   - task_675 (row 360)
#   - task_681 (row 361)
#   - task_686 (row 363)
#   - task_703 (row 368)
#   - task_712 (row 373)
#   - task_710 (row 372)
#   - task_720 (row 377)
#   - task_721 (row 378)
#   - task_723 (row 379)
#   - task_717 (row 376)
#   - task_725 (row 380)
#   - task_732 (row 383)
#   - task_736 (row 386)
#   - task_737 (row 387)
#   - task_733 (row 384)
#   - task_741 (row 389)
#   - task_740 (row 388)
#   - task_742 (row 390)
#   - task_745 (row 392)
#   - task_747 (row 393)
#   - task_760 (row 399)
#   - task_765 (row 401)
#   - task_762 (row 400)
#   - task_772 (row 403)
#   - task_779 (row 408)
#   - task_790 (row 412)
#   - task_801 (row 415)
#   - task_800 (row 414)
#   - task_818 (row 423)
#   - task_814 (row 421)
#   - task_820 (row 425)
#   - task_832 (row 431)
#   - task_830 (row 429)
#   - task_831 (row 430)
#   - task_837 (row 432)
#   - task_840 (row 434)
#   - task_846 (row 437)
#   - task_844 (row 436)
#   - task_849 (row 439)
#   - task_848 (row 438)
#   - task_859 (row 442)
#   - task_856 (row 441)
#   - task_861 (row 443)
#   - task_870 (row 446)
#   - task_866 (row 445)
#   - task_873 (row 449)
#   - task_872 (row 448)
#   - task_881 (row 451)
#   - task_887 (row 454)
#   - task_890 (row 456)
#   - task_892 (row 457)
#   - task_889 (row 455)
#   - task_900 (row 460)
#   - task_901 (row 461)
#   - task_537 (row 285)
#   - task_907 (row 466)
#   - task_914 (row 467)
#   - task_924 (row 472)
#   - task_921 (row 470)
#   - task_928 (row 474)
#   - task_929 (row 475)
#   - task_936 (row 478)
#   - task_933 (row 477)
#   - task_940 (row 481)
#   - task_941 (row 482)
#   - task_950 (row 488)
#   - task_961 (row 494)
#   - task_958 (row 492)
#   - task_949 (row 487)
#   - task_967 (row 498)
#   - task_982 (row 504)
#   - task_989 (row 507)
#   - task_985 (row 506)
#   - task_984 (row 505)
#   - task_999 (row 513)
#   - task_1002 (row 514)
#   - task_1009 (row 517)
#   - task_1006 (row 516)
#   - task_1013 (row 520)
#   - task_1014 (row 521)
#   - task_1019 (row 524)
#   - task_1018 (row 523)
#   - task_1020 (row 525)
#   - task_1024 (row 528)
#   - task_1025 (row 529)
#   - task_1021 (row 526)
#   - task_1028 (row 531)
#   - task_1033 (row 534)
#   - task_1034 (row 535)
#   - task_1036 (row 536)
#   - task_1042 (row 539)
#   - task_1044 (row 541)
#   - task_1046 (row 542)
#   - task_1051 (row 544)
#   - task_1052 (row 545)
#   - task_1055 (row 547)
#   - task_1068 (row 553)
#   - task_1063 (row 551)
#   - task_1071 (row 556)
#   - task_1069 (row 554)
#   - task_1081 (row 561)
#   - task_1084 (row 563)
#   - task_1077 (row 559)
#   - task_1087 (row 564)
#   - task_1095 (row 569)
#   - task_1091 (row 567)
#   - task_1094 (row 568)
#   - task_1100 (row 573)
#   - task_1104 (row 577)
#   - task_1111 (row 579)
#   - task_1117 (row 581)
#   - task_1107 (row 578)
#   - task_1118 (row 582)
#   - task_1120 (row 583)
#   - task_743 (row 391)
#   - task_1129 (row 587)
#   - task_1135 (row 590)
#   - task_1132 (row 589)
#   - task_1144 (row 595)
#   - task_1145 (row 596)
#   - task_1148 (row 597)
#   - task_1151 (row 600)
#   - task_1159 (row 603)
#   - task_1155 (row 602)
#   - task_1165 (row 604)
#   - task_1166 (row 605)
#   - task_1169 (row 607)
#   - task_1176 (row 611)
#   - task_1180 (row 613)
#   - task_1173 (row 610)
#   - task_1184 (row 615)
#   - task_1190 (row 618)
#   - task_1194 (row 620)
#   - task_1199 (row 621)
#   - task_1212 (row 627)
#   - task_1208 (row 626)
#   - task_1215 (row 628)
#   - task_1203 (row 623)
#   - task_1207 (row 625)
#   - task_1227 (row 633)
#   - task_1242 (row 639)
#   - task_1249 (row 643)
#   - task_1250 (row 644)
#   - task_1243 (row 640)
#   - task_1256 (row 648)
#   - task_1254 (row 646)
#   - task_1262 (row 650)
#   - task_1271 (row 653)
#   - task_1263 (row 651)
#   - task_1253 (row 645)
#   - task_1264 (row 652)
#   - task_1277 (row 656)
#   - task_1278 (row 657)
#   - task_1284 (row 659)
#   - task_1286 (row 660)
#   - task_1302 (row 663)
#   - task_1308 (row 666)
#   - task_1331 (row 674)
#   - task_1320 (row 669)
#   - task_1334 (row 675)
#   - task_1324 (row 671)
#   - task_1311 (row 667)
#   - task_1330 (row 673)
#   - task_1322 (row 670)
#   - task_1335 (row 676)
#   - task_1339 (row 679)
#   - task_1338 (row 678)
#   - task_1342 (row 682)
#   - task_1350 (row 685)
#   - task_1341 (row 681)
#   - task_1359 (row 688)
#   - task_1357 (row 687)
#   - task_1354 (row 686)
#   - task_1363 (row 691)
#   - task_1372 (row 696)
#   - task_1361 (row 689)
#   - task_1371 (row 695)
#   - task_1376 (row 698)
#   - task_1374 (row 697)
#   - task_1391 (row 707)
#   - task_1387 (row 704)
#   - task_1394 (row 709)
#   - task_1390 (row 706)
#   - task_1393 (row 708)
#   - task_1399 (row 711)
#   - task_1401 (row 712)
#   - task_1404 (row 714)
#   - task_1409 (row 716)
#   - task_1406 (row 715)
#   - task_1420 (row 720)
#   - task_1414 (row 718)
#   - task_1434 (row 728)
#   - task_1425 (row 725)
#   - task_1432 (row 727)
#   - task_1423 (row 723)
#   - task_1439 (row 731)
#   - task_1443 (row 732)
#   - task_1458 (row 738)
#   - task_1456 (row 737)
#   - task_1460 (row 739)
#   - task_1453 (row 736)
#   - task_1447 (row 734)
#   - task_1462 (row 740)
#   - task_1468 (row 743)
#   - task_1473 (row 746)
#   - task_1474 (row 747)
#   - task_1482 (row 752)
#   - task_1480 (row 751)
#   - task_1499 (row 759)
#   - task_1509 (row 761)
#   - task_1515 (row 765)
#   - task_1516 (row 766)
#   - task_1489 (row 755)
#   - task_1528 (row 772)
#   - task_1524 (row 770)
#   - task_1536 (row 777)
#   - task_1539 (row 778)
#   - task_1531 (row 774)
#   - task_1547 (row 783)
#   - task_1542 (row 781)
#   - task_1544 (row 782)
#   - task_1548 (row 784)
#   - task_1549 (row 785)
#   - task_1554 (row 788)
#   - task_1551 (row 786)
#   - task_1555 (row 789)
#   - task_1558 (row 790)
#   - task_1560 (row 792)
#   - task_1569 (row 795)
#   - task_1571 (row 797)
#   - task_1576 (row 799)
#   - task_1572 (row 798)
#   - task_1579 (row 802)
#   - task_1568 (row 794)
#   - task_1580 (row 803)
#   - task_1584 (row 806)
#   - task_1583 (row 805)
#   - task_1592 (row 810)
#   - task_1591 (row 809)
#   - task_1589 (row 808)
#   - task_1599 (row 813)
#   - task_1601 (row 814)
#   - task_1597 (row 812)
#   - task_1609 (row 818)
#   - task_1607 (row 817)
#   - task_1635 (row 827)
#   - task_1625 (row 823)
#   - task_1633 (row 826)
#   - task_1639 (row 830)
#   - task_1642 (row 832)
#   - task_1637 (row 828)
#   - task_1657 (row 839)
#   - task_1651 (row 836)
#   - task_1664 (row 844)
#   - task_1658 (row 840)
#   - task_1668 (row 846)
#   - task_1667 (row 845)
#   - task_1673 (row 849)
#   - task_1672 (row 848)
#   - task_1675 (row 850)
#   - task_1682 (row 853)
#   - task_1679 (row 851)
#   - task_1685 (row 855)
#   - task_1686 (row 856)
#   - task_1689 (row 859)
#   - task_1697 (row 863)
#   - task_1640 (row 831)
#   - task_1693 (row 861)
#   - task_1704 (row 867)
#   - task_1707 (row 868)
#   - task_1711 (row 870)
#   - task_1708 (row 869)
#   - task_1716 (row 873)
#   - task_1722 (row 876)
#   - task_1720 (row 875)
#   - task_1719 (row 874)
#   - task_1727 (row 880)
#   - task_1724 (row 878)
#   - task_1730 (row 883)
#   - task_1737 (row 885)
#   - task_1738 (row 886)
#   - task_1741 (row 888)
#   - task_1739 (row 887)
#   - task_1754 (row 896)
#   - task_1760 (row 900)
#   - task_1762 (row 901)
#   - task_1756 (row 897)
#   - task_1771 (row 903)
#   - task_1772 (row 904)
#   - task_1773 (row 905)
#   - task_1790 (row 912)
#   - task_1792 (row 913)
#   - task_1786 (row 909)
#   - task_1795 (row 916)
#   - task_1803 (row 920)
#   - task_1808 (row 924)
#   - task_1796 (row 917)
#   - task_1807 (row 923)
#   - task_1811 (row 925)
#   - task_1821 (row 928)
#   - task_1823 (row 930)
#   - task_1824 (row 931)
#   - task_1831 (row 935)
#   - task_1828 (row 933)
#   - task_1834 (row 938)
#   - task_1846 (row 945)
#   - task_1847 (row 946)
#   - task_1853 (row 950)
#   - task_1845 (row 944)
#   - task_1856 (row 952)
#   - task_1854 (row 951)
#   - task_1858 (row 953)
#   - task_1849 (row 948)
#   - task_1871 (row 958)
#   - task_1872 (row 959)
#   - task_1879 (row 962)
#   - task_1874 (row 960)
#   - task_1901 (row 968)
#   - task_1900 (row 967)
#   - task_1902 (row 969)
#   - task_1903 (row 970)
#   - task_1905 (row 971)
#   - task_1914 (row 974)
#   - task_1911 (row 972)
#   - task_1917 (row 976)
#   - task_1920 (row 977)
#   - task_1922 (row 978)
#   - task_1916 (row 975)
#   - task_1924 (row 979)
#   - task_1929 (row 983)
#   - task_1930 (row 984)
#   - task_1927 (row 982)
#   - task_1958 (row 991)
#   - task_1933 (row 986)
#   - task_1963 (row 993)
#   - task_1965 (row 994)
#   - task_1967 (row 995)
#   - task_1971 (row 997)
#   - task_1970 (row 996)
#   - task_1973 (row 998)
#   - task_1983 (row 1000)
#   - task_1975 (row 999)
#   - task_1995 (row 1004)
#   - task_2005 (row 1011)
#   - task_2000 (row 1007)
#   - task_2019 (row 1018)
#   - task_2014 (row 1017)
#   - task_2010 (row 1015)
#   - task_2024 (row 1020)
#   - task_2038 (row 1026)
#   - task_2031 (row 1023)
#   - task_2044 (row 1029)
#   - task_2046 (row 1031)
#   - task_2054 (row 1037)
#   - task_2058 (row 1038)
#   - task_2074 (row 1045)
#   - task_2079 (row 1046)
#   - task_2083 (row 1048)
#   - task_2103 (row 1060)
#   - task_2097 (row 1057)
#   - task_2095 (row 1056)
#   - task_2102 (row 1059)
#   - task_2108 (row 1062)
#   - task_2099 (row 1058)
#   - task_2110 (row 1064)
#   - task_2115 (row 1067)
#   - task_2117 (row 1069)
#   - task_2125 (row 1072)
#   - task_2119 (row 1070)
#   - task_2120 (row 1071)
#   - task_2132 (row 1073)
#   - task_2134 (row 1074)
#   - task_2136 (row 1075)
#   - task_2138 (row 1076)
#   - task_2142 (row 1079)
#   - task_2146 (row 1082)
#   - task_2140 (row 1078)
#   - task_2147 (row 1083)
#   - task_2149 (row 1085)
#   - task_2148 (row 1084)
#   - task_2153 (row 1087)
#   - task_2161 (row 1090)
#   - task_2162 (row 1091)
#   - task_2168 (row 1095)
#   - task_2172 (row 1097)
#   - task_2178 (row 1102)
#   - task_2183 (row 1104)
#   - task_2179 (row 1103)
#   - task_2187 (row 1106)
#   - task_2177 (row 1101)
#   - task_2190 (row 1108)
#   - task_2189 (row 1107)
#   - task_2191 (row 1109)
#   - task_2192 (row 1110)
#   - task_2195 (row 1111)
#   - task_2197 (row 1112)
#   - task_2201 (row 1115)
#   - task_2203 (row 1116)
#   - task_2199 (row 1113)
#   - task_2205 (row 1117)
#   - task_2207 (row 1118)
#   - task_2217 (row 1125)
#   - task_2224 (row 1130)
#   - task_2227 (row 1131)
#   - task_2218 (row 1126)
#   - task_2232 (row 1134)
#   - task_2235 (row 1136)
#   - task_2233 (row 1135)
#   - task_2239 (row 1139)
#   - task_2238 (row 1138)
#   - task_2230 (row 1133)
#   - task_2245 (row 1142)
#   - task_2254 (row 1145)
#   - task_2258 (row 1147)
#   - task_2263 (row 1150)
#   - task_2262 (row 1149)
#   - task_2264 (row 1151)
#   - task_2266 (row 1153)
#   - task_2267 (row 1154)
#   - task_2274 (row 1155)
#   - task_2284 (row 1158)
#   - task_2283 (row 1157)
#   - task_2288 (row 1160)
#   - task_2287 (row 1159)
#   - task_2291 (row 1162)
#   - task_2290 (row 1161)
#   - task_2293 (row 1164)
#   - task_2298 (row 1166)
#   - task_2300 (row 1167)
#   - task_2301 (row 1168)
#   - task_2310 (row 1174)
#   - task_2314 (row 1176)
#   - task_2312 (row 1175)
#   - task_2308 (row 1172)
#   - task_2328 (row 1181)
#   - task_2317 (row 1178)
#   - task_2329 (row 1182)
#   - task_2323 (row 1179)
#   - task_2338 (row 1185)
#   - task_2340 (row 1186)
#   - task_2345 (row 1190)
#   - task_2348 (row 1192)
#   - task_2369 (row 1203)
#   - task_2354 (row 1198)
#   - task_2349 (row 1193)
#   - task_2353 (row 1197)
#   - task_2377 (row 1209)
#   - task_2378 (row 1210)
#   - task_2381 (row 1212)
#   - task_2387 (row 1213)
#   - task_2388 (row 1214)
#   - task_2390 (row 1216)
#   - task_2376 (row 1208)
#   - task_2389 (row 1215)
#   - task_2392 (row 1217)
#   - task_2394 (row 1219)
#   - task_2393 (row 1218)
#   - task_2395 (row 1220)
#   - task_2399 (row 1222)
#   - task_2408 (row 1224)
#   - task_2402 (row 1223)
#   - task_2415 (row 1230)
#   - task_2413 (row 1228)
#   - task_2414 (row 1229)
#   - task_2418 (row 1232)
#   - task_2421 (row 1235)
#   - task_2422 (row 1236)
#   - task_2416 (row 1231)
#   - task_2419 (row 1233)
#   - task_2424 (row 1237)
#   - task_2426 (row 1238)
#   - task_2427 (row 1239)
#   - task_2429 (row 1240)
#   - task_2435 (row 1242)
#   - task_2438 (row 1245)
#   - task_2441 (row 1246)
#
# ================================================================================

# %%
import pandas as pd
import glob
from datetime import datetime

# Read the original parquet file
df = pd.read_parquet('clean_julia_set_3.parquet')
print(f"Original dataset: {len(df)} rows")

# Find the most recent failed_tasks CSV file
failed_files = glob.glob('failed_tasks_*.csv')

if not failed_files:
    print("\n❌ No failed_tasks CSV file found!")
    print("Please run the test script first to generate failed tasks.")
    exit()

# Get the most recent file
latest_failed_file = max(failed_files, key=lambda x: x.split('_')[2])
print(f"\nUsing failed tasks from: {latest_failed_file}")

# Read the failed tasks
failed_df = pd.read_csv(latest_failed_file)
failed_task_ids = failed_df['task_id'].tolist()

print(f"Failed tasks to remove: {len(failed_task_ids)}")
print(f"\nFailed task IDs:")
for task_id in failed_task_ids:
    print(f"  - {task_id}")

# Remove failed tasks
df_filtered = df[~df['task_id'].isin(failed_task_ids)]

print(f"\n{'='*80}")
print(f"Original rows: {len(df)}")
print(f"Failed rows removed: {len(failed_task_ids)}")
print(f"Remaining rows: {len(df_filtered)}")
print(f"{'='*80}")

# Save the filtered dataset
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_file = f'cleaned_file_passed_only_{timestamp}.parquet'
df_filtered.to_parquet(output_file, index=False)

print(f"\n✅ Filtered dataset saved to: {output_file}")
print(f"Success rate: {len(df_filtered)/len(df)*100:.2f}%")
# Out:
# Original dataset: 1000 rows
#
# Using failed tasks from: failed_tasks_20251026_085318.csv
# Failed tasks to remove: 387
#
# Failed task IDs:
#   - task_1235
#   - task_1236
#   - task_1237
#   - task_1244
#   - task_1245
#   - task_1252
#   - task_1257
#   - task_1266
#   - task_1267
#   - task_1268
#   - task_1269
#   - task_1273
#   - task_1280
#   - task_1281
#   - task_1282
#   - task_1285
#   - task_1287
#   - task_1288
#   - task_1289
#   - task_1290
#   - task_1291
#   - task_1293
#   - task_1294
#   - task_1295
#   - task_1296
#   - task_1297
#   - task_1298
#   - task_1299
#   - task_1305
#   - task_1307
#   - task_1309
#   - task_1310
#   - task_1312
#   - task_1314
#   - task_1316
#   - task_1318
#   - task_1321
#   - task_1323
#   - task_1325
#   - task_1326
#   - task_1327
#   - task_1329
#   - task_1336
#   - task_1343
#   - task_1344
#   - task_1346
#   - task_1351
#   - task_1352
#   - task_1356
#   - task_1358
#   - task_1360
#   - task_1365
#   - task_1367
#   - task_1369
#   - task_1370
#   - task_1373
#   - task_1378
#   - task_1385
#   - task_1386
#   - task_1395
#   - task_1397
#   - task_1400
#   - task_1402
#   - task_1407
#   - task_1408
#   - task_1413
#   - task_1415
#   - task_1416
#   - task_1417
#   - task_1419
#   - task_1426
#   - task_1430
#   - task_1436
#   - task_1440
#   - task_1444
#   - task_1445
#   - task_1450
#   - task_1455
#   - task_1457
#   - task_1459
#   - task_1461
#   - task_1465
#   - task_1466
#   - task_1467
#   - task_1471
#   - task_1477
#   - task_1478
#   - task_1484
#   - task_1485
#   - task_1487
#   - task_1490
#   - task_1491
#   - task_1492
#   - task_1502
#   - task_1503
#   - task_1504
#   - task_1505
#   - task_1506
#   - task_1507
#   - task_1508
#   - task_1514
#   - task_1517
#   - task_1519
#   - task_1520
#   - task_1526
#   - task_1532
#   - task_1533
#   - task_1537
#   - task_1545
#   - task_1546
#   - task_1550
#   - task_1557
#   - task_1561
#   - task_1562
#   - task_1563
#   - task_1564
#   - task_1565
#   - task_1574
#   - task_1575
#   - task_1585
#   - task_1587
#   - task_1590
#   - task_1593
#   - task_1600
#   - task_1602
#   - task_1608
#   - task_1612
#   - task_1615
#   - task_1619
#   - task_1622
#   - task_1624
#   - task_1628
#   - task_1629
#   - task_1630
#   - task_1631
#   - task_1634
#   - task_1643
#   - task_1644
#   - task_1645
#   - task_1646
#   - task_1647
#   - task_1654
#   - task_1663
#   - task_1665
#   - task_1669
#   - task_1671
#   - task_1676
#   - task_1677
#   - task_1678
#   - task_1681
#   - task_1690
#   - task_1694
#   - task_1696
#   - task_1698
#   - task_1699
#   - task_1705
#   - task_1706
#   - task_1713
#   - task_1715
#   - task_1717
#   - task_1721
#   - task_1726
#   - task_1731
#   - task_1732
#   - task_1735
#   - task_1736
#   - task_1745
#   - task_1749
#   - task_1750
#   - task_1751
#   - task_1752
#   - task_1755
#   - task_1761
#   - task_1766
#   - task_1767
#   - task_1770
#   - task_1776
#   - task_1778
#   - task_1779
#   - task_1781
#   - task_1782
#   - task_1784
#   - task_1785
#   - task_1789
#   - task_1791
#   - task_1797
#   - task_1798
#   - task_1800
#   - task_1806
#   - task_1810
#   - task_1812
#   - task_1815
#   - task_1817
#   - task_1818
#   - task_1819
#   - task_1820
#   - task_1825
#   - task_1826
#   - task_1830
#   - task_1836
#   - task_1841
#   - task_1842
#   - task_1857
#   - task_1859
#   - task_1860
#   - task_1862
#   - task_1868
#   - task_1869
#   - task_1870
#   - task_1873
#   - task_1877
#   - task_1878
#   - task_1881
#   - task_1882
#   - task_1883
#   - task_1884
#   - task_1885
#   - task_1886
#   - task_1887
#   - task_1889
#   - task_1890
#   - task_1892
#   - task_1896
#   - task_1898
#   - task_1899
#   - task_1904
#   - task_1906
#   - task_1907
#   - task_1909
#   - task_1910
#   - task_1913
#   - task_1915
#   - task_1918
#   - task_1919
#   - task_1923
#   - task_1928
#   - task_1932
#   - task_1938
#   - task_1939
#   - task_1940
#   - task_1941
#   - task_1942
#   - task_1944
#   - task_1945
#   - task_1946
#   - task_1948
#   - task_1951
#   - task_1952
#   - task_1953
#   - task_1954
#   - task_1955
#   - task_1959
#   - task_1966
#   - task_1976
#   - task_1977
#   - task_1978
#   - task_1979
#   - task_1980
#   - task_1982
#   - task_1984
#   - task_1985
#   - task_1987
#   - task_1989
#   - task_1992
#   - task_1993
#   - task_2012
#   - task_2016
#   - task_2017
#   - task_2018
#   - task_2020
#   - task_2023
#   - task_2025
#   - task_2026
#   - task_2029
#   - task_2030
#   - task_2033
#   - task_2039
#   - task_2040
#   - task_2043
#   - task_2047
#   - task_2052
#   - task_2055
#   - task_2057
#   - task_2060
#   - task_2061
#   - task_2065
#   - task_2069
#   - task_2075
#   - task_2077
#   - task_2078
#   - task_2080
#   - task_2082
#   - task_2085
#   - task_2098
#   - task_2106
#   - task_2107
#   - task_2114
#   - task_2118
#   - task_2121
#   - task_2122
#   - task_2123
#   - task_2127
#   - task_2129
#   - task_2130
#   - task_2131
#   - task_2133
#   - task_2141
#   - task_2150
#   - task_2152
#   - task_2155
#   - task_2158
#   - task_2160
#   - task_2165
#   - task_2180
#   - task_2181
#   - task_2184
#   - task_2185
#   - task_2193
#   - task_2194
#   - task_2198
#   - task_2206
#   - task_2216
#   - task_2220
#   - task_2223
#   - task_2225
#   - task_2229
#   - task_2234
#   - task_2237
#   - task_2240
#   - task_2241
#   - task_2243
#   - task_2247
#   - task_2248
#   - task_2249
#   - task_2250
#   - task_2255
#   - task_2259
#   - task_2269
#   - task_2270
#   - task_2271
#   - task_2272
#   - task_2273
#   - task_2277
#   - task_2278
#   - task_2280
#   - task_2285
#   - task_2286
#   - task_2289
#   - task_2294
#   - task_2297
#   - task_2299
#   - task_2302
#   - task_2311
#   - task_2313
#   - task_2318
#   - task_2319
#   - task_2321
#   - task_2322
#   - task_2325
#   - task_2326
#   - task_2332
#   - task_2339
#   - task_2346
#   - task_2356
#   - task_2357
#   - task_2360
#   - task_2364
#   - task_2365
#   - task_2366
#   - task_2367
#   - task_2382
#   - task_2383
#   - task_2386
#   - task_2397
#   - task_2398
#   - task_2404
#   - task_2406
#   - task_2407
#   - task_2410
#   - task_2417
#   - task_2423
#   - task_2425
#   - task_2428
#   - task_2430
#   - task_2432
#   - task_2434
#   - task_2440
#
# ================================================================================
# Original rows: 1000
# Failed rows removed: 387
# Remaining rows: 613
# ================================================================================
#
# ✅ Filtered dataset saved to: cleaned_file_passed_only_20251026_085531.parquet
# Success rate: 61.30%

# %%
pwd
# Out:
# '/workspace/AIAC'
